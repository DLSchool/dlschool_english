# %% [markdown]
# # HW 2:
# Numpy and linear algebra

# %% [markdown]
# Import libs:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps

from scipy import misc 

# %matplotlib inline

# %% [markdown]
# *questions for self-control:*
# 1. What is NumPy?
# 2. Why It works quicker? For what purpose?
# 3. Why do we need linear algebra in DL domain?

# %% [markdown]
# ### Task 1

# %% [markdown]
# In the first task you are supposed to multiply two square matrices in two ways - without using the numpy package and with it.

# %%
# Random objects are used to generate matrices - it is used to generate random objects
# the sample function creates a random sample. In this argument, a tuple (i, j) is passed to it, 
# here i is the number of rows, j is the number of columns.
a = np.random.sample((10,10))
b = np.random.sample((10,10))
# enter the dimension (rank) of each matrix using the ndim function.
# Use the shape function
# ========
# here you can write code
# ========
print(a)
print(b)
# Out:
# [[0.73279847 0.55352034 0.66776063 0.10039117 0.24273249 0.80549754
#   0.16116584 0.75615408 0.40959121 0.31430532]
#  [0.31725745 0.99460467 0.51970165 0.11410669 0.62445917 0.50438959
#   0.81052529 0.05608756 0.99913264 0.11513063]
#  [0.61052299 0.60592485 0.94155634 0.54341088 0.40276022 0.12709334
#   0.75120152 0.52331581 0.08299209 0.1050127 ]
#  [0.95546251 0.61394772 0.74616664 0.40807817 0.72934059 0.67291685
#   0.22232937 0.44665697 0.36980073 0.12653346]
#  [0.5694063  0.65478599 0.02612649 0.04753569 0.97801784 0.50610065
#   0.02139513 0.77532965 0.60010015 0.46072411]
#  [0.54384145 0.45544897 0.10432678 0.66226788 0.96865873 0.50095606
#   0.05741878 0.88134126 0.24726751 0.18971707]
#  [0.20487817 0.9226313  0.5023741  0.74261787 0.2767994  0.57522835
#   0.34474363 0.57795585 0.67302982 0.39947352]
#  [0.77054138 0.95552544 0.04176001 0.84311766 0.54901144 0.74002821
#   0.55116559 0.23128088 0.40482408 0.08296293]
# ...

# %%
def mult(a, b):
    # here code matrix multiplication without
    # NumPy and print the result
    pass

# %%
def np_mult(a, b):
    # here write matrix multiplication with
    # use numpy and output the result
    pass

# %%
# %%time
# notice the function time without Numpy
mult(a,b)

# %%
# %%time
# notice the function time with Numpy
np_mult(a,b)

# %% [markdown]
# ### Task 2

# %% [markdown]
# Write a function that builds a sequence $\{A_i\}_{i=1}^n$ from a given sequence $S_n$, where $S_k = \frac{A_1 + ... + A_k}{k}$.
# Similarly, with the help of the NumPy library and without it. Compare the speed, explain the result.

# %%
# function solving the problem with NumPy
def sec_av (A):
    # Your code is here.
    pass

# %%
# function without NumPy
def stupid_sec_av (A):
    S = [0 for i in range (len (A))]
# Your code is here.
    return s

# set some sequence and check it on your functions.
# The first function should work ~ 50 times faster.
A = sps.uniform.rvs (size = 10 ** 7)

% time S1 = sec_av (A)
% time S2 = stupid_sec_av (A)
Check for correctness:
np.abs (S1 - S2) .sum ()

# %% [markdown]
# ### Task 3

# %% [markdown]
# Let some array $ X $ be given. We need to build a new array, where all elements with odd indices need to be replaced by the number $ a $ (if it is not specified, then by 1). All even-numbered elements of the original array need to be cubed and written in reverse order relative to the positions of these elements. The $ X $ array should remain unchanged. At the end, you need to merge the $ X $ array with the transformed $ X $ and output in the reverse order.

# %%
# function solving the problem with NumPy
def transformation (X, a = 1):
    # Your code is here.
    return Y

# %%
# function solving the problem without NumPy
def stupid_transformation (X):
    # Your code is here.
    return Y

# %%
X = sps.uniform.rvs (size = 10 ** 7)
# this code is about 20 times more efficient.
# if you are thinking of printing an array without np - better look at its size first
% time S1 = transformation (X)
% time S2 = stupid_transformation (X)
Check for correctness:
np.abs (S1 - S2) .sum ()

# %% [markdown]
# What did you mentioned about using NumPy package for calculations?
#
# **Answer:**

# %% [markdown]
# ### Task 4

# %% [markdown]
# You are given two vectors `a` and` b` in three-dimensional space. Fill them with random numbers. Implement their scalar product with and without `NumPy`. Note the work time, as shown in the tasks above.

# %%
a = # here is your code
b = # here is your code

# %%
def stupid_scalar_product(a,b):
    # # here is your code

# %%
def numpy_scalar_product(a,b):
    # here is your code

# %%
# %time product_1 = stupid_scalar_product(a,b)
# %time product_2 = numpy_scalar_product(a,b)
# lets check correctness
np.abs(product_1 - product_2).sum()

# %% [markdown]
# ## Bonus part (no questions on this part in the test)

# %% [markdown]
# ### Task 1*

# %% [markdown]
# Image us 2-D numerical array
# (or 3-D: CT, MRI, 2D + time; 4-D, ...)
# In the current task, image is Numpy array (np.array)

# %%
# built-in library function that loads a picture with a raccoon
pic = misc.face()

# %% [markdown]
# Print type and shape of pic.

# %%
print(# here is your code)

# %% [markdown]
# If everything is correct, shape is (X, Y, 3). Why we have 3 in the last position?
#
#
# **Answer:**

# %% [markdown]
# Let's look on this pic:

# %%
plt.imshow(pic)

# %% [markdown]
# Make sure that inside the array `pic` we really have numbers. Output the first 10 entries.
# The array consists of triples of numbers that characterize the color depth for each pixel.

# %% [markdown]
# Now let's load a black and white image of a raccoon so that our array is not a 3-D tensor, but a 2-D array. Tensors are processed in the same way, but for simplicity, for now let's work with two-dimensional arrays, i.e. matrices.

# %%
pic = misc.face(gray=True)

# %%
plt.imshow(# here is your code)

# %% [markdown]
# Print the shape of the resulting pic image. What conclusions can be made? Put in the `h`,` w` height and width of the image.

# %%
print (# your code here)
h, w = # here is your code

# %% [markdown]
# Using the `numpy` library, flip the image horizontally. Print the picture.
#
# Hint: don't forget that images are just two-dimensional arrays

# %%
# here is your code

# %% [markdown]
# Now let's increase the contrast level - to do this, add 50 units to each pixel

# %%
# here is your code

# %%
# let's check the result
plt.imshow(pic)

# %% [markdown]
# Now let's try to turn our single-channel image into a three-channel (RGB) tensor. To do this, instead of each pixel in a single-channel image (in a two-dimensional array) we put a tuple of three elements - the depths of red, green and blue, respectively. We cannot restore the black and white color image, since we cannot take the lost information from nowhere, but we can strengthen the black and white areas. To do this, let's fill all three channels with the same values divided by something very large. For example $ - $ on $ 200 $. That is, for example, if the pixel `pic [i] [j]` had the value ** 200 **, then for the new image `new_pic` we fill in` new_pic [i] [j] `with a tuple of three numbers` int ( pic [i] [j] / 3) `. The `int` $ - $ function rounds to the integer part.

# %%
new_pic = np.zeros((h,w,3)) # creating empty matrix
for i in range(h):
    for j in range(w):
     # here is your code

# %%
# finally, let's check the result
plt.imshow(pic)

# %% [markdown]
# Now let's reduce the picture quality by 16 times, by reducing the image quality, i.e. Now 16 pixels in proximity should be filled with one value.

# %%
from sklearn.datasets import load_sample_image # import picture loader

# %%
china = load_sample_image('china.jpg') # example pic from library above
plt.imshow(china)

# %% [markdown]
# Put in variables `h`,` w`, `c` height, width, number of channels, respectively, for the picture` china`.

# %%
h, w, c = # here is your code

# %% [markdown]
# Now let's go straight to changing the image $ - $ we suggest dividing the pictures into squares 4 by 4 and filling in all 16 values inside the square with the left upper value. You can do otherwise.

# %%
from copy import copy
compressed_pic = copy(china)
# here is your code

# %% [markdown]
# Write a function that considers the discrepancy between the original and compressed image. Run your code for `compressed_pic`,` china`

# %%
def calculate_mismatch(a,b):
    mismatch=0
    # here is your code
    print(mismatch)

# %%
calculate_mismatch(# here is your code)

# %% [markdown]
# ### Task 2*

# %% [markdown]
# Now let's work with audio files. A standard audio file is a regular set of numbers in which the values of frequencies captured at regular intervals are stored. So, the simplest audio track $ is a $ one-dimensional array.
#
# The first thing you need to do $ - $ install a library to work with audio. It is called `librosa`. Installation Guide: https://librosa.github.io/librosa/install.html

# %%
import librosa 
import IPython.display # library with widgets to display audios in notebook

# %%
audio, sr= librosa.load('Test.wav')  
# write our array of sound frequencies to an audio file, sr is the number of points 
# recorded per second. For the file to open, it must be in the same folder as the HW_2.ipynb 
# file (or you must pass the full pass to the file)

# %% [markdown]
# Let's play audio in `.ipynb`:

# %%
IPython.display.Audio(audio)

# %% [markdown]
# Print the data type of the variable `audio`, find its duration and average value.

# %%
print(# your code is here)

# %% [markdown]
# Let's see what our path looks like. To do this, use the library `matplotlib.pyplot`

# %%
plt.figure(figsize=(25,5))
plt.title('Test.wav')
plt.plot(audio)

# %% [markdown]
# cut the last 4 sec from audiofile

# %%
audio = # your code is here

# %% [markdown]
# Let's reduce the amplitude by 25%. What will change? I remind you that you can always listen to the changes with `IPython.display.Audio`

# %%
audio = # your code is here

# %% [markdown]
# And the audio track can be accelerated. To do this, try to try the `rate` parameter

# %%
IPython.display.Audio(audio, rate=sr)
