# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg"  width=500 height=400></p>
#
# <h3 style="text-align: center;"><b>Phystech School of Applied Mathematics and Informatics</b></h3>

# %% [markdown]
# # Seminar 1 Bash

# %%
! curl 'http://vis-www.cs.umass.edu/lfw/lfw.tgz' -H 'Connection: keep-alive' -H 'Upgrade-Insecure-Requests: 1' -H 'DNT: 1'  -H 'Referer: http://vis-www.cs.umass.edu/lfw/' -H 'Accept-Encoding: gzip, deflate'  --compressed --output lfw.tgz

# %%
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/socket.io/?authuser=0&EIO=3&transport=polling&t=MZItRN3&sid=PNxLoh3EzS9A5V8-AAAO' -H 'origin: https://colab.research.google.com' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYvFUeVdiDP6DC5ZBic5UKMzJal7ps0XobrsPqk4XDYnQ_SfWhQ2zYmGuz4QzR2lzcms-Cc' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' -H 'x-colab-tunnel: Google' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'content-type: text/plain;charset=UTF-8' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'dnt: 1' --data-binary '1:2' --compressed ;
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/socket.io/?authuser=0&EIO=3&transport=polling&t=MZItRUl&sid=PNxLoh3EzS9A5V8-AAAO' -H 'dnt: 1' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYt8cSRn_ISS090SGYF_1qB6vKDYmbeMjVoCswyuznOIc4Bt5sPucWuOLbXzKIf55OkkWDI' -H 'x-colab-tunnel: Google' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' --compressed ;
# !curl 'https://clients6.google.com/drive/v2beta/files/1q26iOlJGjQdOGQGIn1d1YvxU9lmp-yXY?supportsTeamDrives=true&fields=headRevisionId&path=%2Fv2internal%2Ffiles&key=AIzaSyCN_sSPJMpYrAzC5AtTrltNC8oRmLtoqBk&%24unique=gc144' -H 'cookie: __utmc=173272373; __utma=173272373.1690889903.1543850294.1543850294.1544924404.2; __utmz=173272373.1544924404.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); CONSENT=YES+RU.ru+20180218-08-0; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; SIDCC=AN0-TYt8cSRn_ISS090SGYF_1qB6vKDYmbeMjVoCswyuznOIc4Bt5sPucWuOLbXzKIf55OkkWDI' -H 'origin: https://colab.research.google.com' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'authorization: SAPISIDHASH 1549725972_5b84ed6d84c5ea7347f5818df3c58bc72ce7d530' -H 'x-requested-with: XMLHttpRequest' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' -H 'x-goog-authuser: 0' -H 'x-clientdetails: appVersion=5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64)%20AppleWebKit%2F537.36%20(KHTML%2C%20like%20Gecko)%20Chrome%2F71.0.3578.98%20Safari%2F537.36&platform=Win32&userAgent=Mozilla%2F5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64)%20AppleWebKit%2F537.36%20(KHTML%2C%20like%20Gecko)%20Chrome%2F71.0.3578.98%20Safari%2F537.36' -H 'x-goog-encode-response-if-executable: base64' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: clients6.google.com' -H 'if-none-match: "YJwHxXFNKFhjdPRfKpkHdJ4HLyo/HAktMW38ulOalgtnExQ12AiRg6E"' -H 'x-javascript-user-agent: google-api-javascript-client/1.1.0' -H 'dnt: 1' --compressed ;
# !curl 'https://colab.research.google.com/analytics?authuser=0' -H 'origin: https://colab.research.google.com' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'content-type: application/x-www-form-urlencoded;charset=UTF-8' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYtZKhG_4Le_WZHGx0Hj1cH170uO5XXc9hCne6KegEhlRQ0KEJ8PeXjFvkFp2ceuv1tf3RI' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' -H 'dnt: 1' --data '{"notebook_name":"[seminar]bash.ipynb","notebook_id":"1q26iOlJGjQdOGQGIn1d1YvxU9lmp-yXY","colab_version_tag":"colab-20190207-085300-RC02_232946277","backend_info":{"type":4,"tunnel_url":"/m/m-2dwzjs2q4fknn"},"drive_api_event":{"resource":3,"method":1,"status":1}}' --compressed ;
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/socket.io/?authuser=0&EIO=3&transport=polling&t=MZItU8V&sid=PNxLoh3EzS9A5V8-AAAO' -H 'origin: https://colab.research.google.com' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYtByPZMoYULIfbUKDqhgMQdxqHb6EK1QUiTfgaffUEGLyDJVt9ZzV5YAgufPK0LIysEM9E' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' -H 'x-colab-tunnel: Google' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'content-type: text/plain;charset=UTF-8' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'dnt: 1' --data-binary '396:42/session,["data",{"data":"{\"header\":{\"msg_id\":\"63ee67f88a8145e8dea720b03bee1899\",\"username\":\"username\",\"session\":\"8b12e22028a740f2ab6ee0f26419d0f4\",\"msg_type\":\"execute_request\"},\"metadata\":{},\"content\":{\"allow_stdin\":false,\"code\":\"\",\"silent\":true,\"store_history\":false,\"user_expressions\":{},\"user_variables\":[]},\"parent_header\":{},\"channel\":\"shell\"}"}]' --compressed ;
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/socket.io/?authuser=0&EIO=3&transport=polling&t=MZItUFK&sid=PNxLoh3EzS9A5V8-AAAO' -H 'dnt: 1' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYvwJsse6A7vUftXS28iWrF1J21pIu0CDLgfRox1ZhEIbkP6hdoF54P0rjRwIKCOlBVzfX4' -H 'x-colab-tunnel: Google' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' --compressed ;
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/socket.io/?authuser=0&EIO=3&transport=polling&t=MZItUJw&sid=PNxLoh3EzS9A5V8-AAAO' -H 'Accept: */*' -H 'Referer: https://colab.research.google.com/' -H 'DNT: 1' -H 'X-Colab-Tunnel: Google' -H 'User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' --compressed ;
# !curl 'https://colab.research.google.com/tun/m/m-2dwzjs2q4fknn/api/colab/resources?authuser=0' -H 'dnt: 1' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: colab.research.google.com' -H 'cookie: CONSENT=YES+RU.ru+20180218-08-0; _ga=GA1.4.368699161.1541443448; _ga=GA1.3.730363366.1545244669; S=billing-ui-v3=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:billing-ui-v3-efe=7voF3LJJqVjKqPTbNXCIeFOYOVDUTGpA:adwords-usermgmt=dtZsgq1NGSvKcKKRCagyAtJMoD3iTFsZ:adwords-diagnostic-fe=9XyhLorQle7WeMKwcf1I9ed83wX0zx37; SID=BQf_-b7c3gopHYZzcTpkvodFnF-BIxW5Bb_ObBm_OlRual4gu8kRW49dKSMuhu357Tfkrg.; HSID=AEeTe28fHAZVvv6vC; SSID=AjQsThseIhF86IWoC; APISID=ppg37yJpJVSkLspC/AMnl3Rc4OY-KklZxp; SAPISID=c8sslhcczXMGklGq/AAkeQl9ixrlFCuLg7; _gid=GA1.4.1899167949.1549353696; NID=158=ZLIgAoN8GhMkSUTtpvlQ__ZU6RxHf9uFke42qxgvgp1u6SYoTEHeS2bXYzhHyuZLj2aBMSA7VwRPjZNvHZgmKh52v2YM10sHYqscOyKH8XF5k6MlNAUyZfo9ITFjbCFkyrMCKxDXR4nInE8Siz_rivicnd6sqxdrjuK3Q7NvqPXi3WWdX9hXlF3N1yLZ5SxiNx1eKT4-JRALEocA33HFGvMM_qFpdhOZMM8_kmzUGXe3FC8rLCYa1FqFhj0BU_0pplO669w5ofpWozOkYzZZ2XQbmVebu-dxM9yZVSixnZYTQZWP6LelEGnV4B8; 1P_JAR=2019-2-9-14; _gat=1; SIDCC=AN0-TYtfnG9x5NbUw0Jx8g94VaBzytDcDcreZ3-fTdHMPgRh9ytfft_IxGxIz9TfG8YME7U9re0' -H 'x-colab-tunnel: Google' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' --compressed ;
# !curl 'https://clients6.google.com/upload/drive/v2internal/files/1q26iOlJGjQdOGQGIn1d1YvxU9lmp-yXY?uploadType=multipart&fields=alternateLink%2Ccapabilities%2FcanReadRevisions%2CdownloadUrl%2CfileSize%2Cid%2Clabels%2CmimeType%2CoriginalFilename%2Cowners%2Cparents%2Cproperties%2Cshared%2CteamDriveId%2Ctitle%2CuserPermission%2CheadRevisionId&precondition=headRevisionId%3D%270Bw4itQWLWYJDZFptOFdnZXQyZ2traGZKVXAvUVBMYUFTUjIwPQ%27&supportsTeamDrives=true&key=AIzaSyCN_sSPJMpYrAzC5AtTrltNC8oRmLtoqBk&%24unique=gc538' -X OPTIONS -H 'access-control-request-headers: authorization,content-type,x-clientdetails,x-goog-authuser,x-goog-encode-response-if-executable,x-javascript-user-agent,x-requested-with' -H 'access-control-request-method: PUT' -H 'origin: https://colab.research.google.com' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6' -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'accept: */*' -H 'referer: https://colab.research.google.com/' -H 'authority: clients6.google.com' -H 'x-client-data: CIu2yQEIpLbJAQjBtskBCKmdygEIqKPKAQi/p8oBCOynygEI4qjKARj5pcoB' -H 'dnt: 1' --compressed ;
# !curl 'https://clients6.google.com/upload/drive/v2internal/files/1q26iOlJGjQdOGQGIn1d1YvxU9lmp-yXY?uploadType=multipart&fields=alternateLink%2Ccapabilities%2FcanReadRevisions%2CdownloadUrl%2CfileSize%2Cid%2Clabels%2CmimeType%2CoriginalFilename%2Cowners%2Cparents%2Cproperties%2Cshared%2CteamDriveId%2Ctitle%2CuserPermission%2CheadRevisionId&precondition=headRevisionId%3D%270Bw4itQWLWYJDZFptOFdnZXQyZ2traGZKVXAvUVBMYUFTUjIwPQ%27&supportsTeamDrives=true&key=AIzaSyCN_sSPJMpYrAzC5AtTrltNC8oRmLtoqBk&%24unique=gc538' -X PUT -H 'Origin: https://colab.research.google.com' -H 'X-ClientDetails: appVersion=5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64)%20AppleWebKit%2F537.36%20(KHTML%2C%20like%20Gecko)%20Chrome%2F71.0.3578.98%20Safari%2F537.36&platform=Win32&userAgent=Mozilla%2F5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64)%20AppleWebKit%2F537.36%20(KHTML%2C%20like%20Gecko)%20Chrome%2F71.0.3578.98%20Safari%2F537.36' -H 'X-Goog-Encode-Response-If-Executable: base64' -H 'Authorization: SAPISIDHASH 1549725985_776e7ae19c8649f62bb75e15b0218b065c6e0658' -H 'Content-Type: multipart/mixed; boundary="-------314159265358979323846"' -H 'User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36' -H 'Referer: https://colab.research.google.com/' -H 'X-Requested-With: XMLHttpRequest' -H 'X-JavaScript-User-Agent: google-api-javascript-client/1.1.0' -H 'X-Goog-AuthUser: 0' -H 'DNT: 1' --data-binary $'\r\n---------314159265358979323846\r\nContent-Type: application/json\r\n\r\n{"title":"[seminar]bash.ipynb","description":"Colaboratory notebook","mimeType":"application/vnd.google.colaboratory","parents":[],"indexableText":{"text":"[seminar]bash.ipynb\\n<p style=\\"align: center;\\"><img align=center src=\\"https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg\\"  width=500 height=400></p>\\n\\n<h3 style=\\"text-align: center;\\"><b>Phystech School of Applied Mathematics and Informatics</b></h3>\\n# Seminar 1 Bash\\n! curl \'http://vis-www.cs.umass.edu/lfw/lfw.tgz\' -H \'Connection: keep-alive\' -H \'Upgrade-Insecure-Requests: 1\' -H \'DNT: 1\'  -H \'Referer: http://vis-www.cs.umass.edu/lfw/\' -H \'Accept-Encoding: gzip, deflate\'  --compressed --output lfw.tgz\\n### wget \\n! wget example.com\\n\\nwith open(\'index.html.1\',\'r\') as f:\\n  for line in f:\\n    print(line)\\n# check the file on fs\\n! ls\\n### tar\\n\\nfilename = \'lfw.tgz\'\\n\\n# Unzip the downloaded tar, write output of \\"tar\\" command to \\"filelist.txt\\"\\n# the output is list of paths to all unzipped files. We can use them to read data. \\n\\n! tar xvzf $filename > filelist.txt\\n### zip\\nfilename = \'human_eva06.zip\'\\n\\n# Unzip the dataset\\n! unzip $filename \\n \\n### Mount a google drive\\n\\nfrom google.colab import drive\\ndrive.mount(\'/content/drive\')\\n"},"properties":[{"key":"revisionCounter","value":"20","visibility":"PUBLIC"},{"key":"disableRealtime","value":"1","visibility":"PUBLIC"}]}\r\n---------314159265358979323846\r\nContent-Type: application/json\r\n\r\n{"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"name":"[seminar]bash.ipynb","version":"0.3.2","provenance":[]},"kernelspec":{"name":"python3","display_name":"Python 3"}},"cells":[{"metadata":{"id":"h2KLvTutK19X","colab_type":"text"},"cell_type":"markdown","source":["<p style=\\"align: center;\\"><img align=center src=\\"https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg\\"  width=500 height=400></p>\\n","\\n","<h3 style=\\"text-align: center;\\"><b>Phystech School of Applied Mathematics and Informatics</b></h3>"]},{"metadata":{"id":"kv5Ft2OMFIUU","colab_type":"text"},"cell_type":"markdown","source":["# Seminar 1 Bash"]},{"metadata":{"id":"qa2ZD32tFWbf","colab_type":"code","colab":{"base_uri":"https://localhost:8080/","height":90},"outputId":"3defbd33-c5fc-4515-f7ea-d9a99d8bacb7","executionInfo":{"status":"ok","timestamp":1549725930748,"user_tz":-180,"elapsed":6526,"user":{"displayName":"Данил Лыков","photoUrl":"https://lh3.googleusercontent.com/-SafJS7sYsKY/AAAAAAAAAAI/AAAAAAAAFQ8/-xeygFBP1uc/s64/photo.jpg","userId":"03645490761692392178"}}},"cell_type":"code","source":["! curl \'http://vis-www.cs.umass.edu/lfw/lfw.tgz\' -H \'Connection: keep-alive\' -H \'Upgrade-Insecure-Requests: 1\' -H \'DNT: 1\'  -H \'Referer: http://vis-www.cs.umass.edu/lfw/\' -H \'Accept-Encoding: gzip, deflate\'  --compressed --output lfw.tgz"],"execution_count":15,"outputs":[{"output_type":"stream","text":["  % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current\\n","                                 Dload  Upload   Total   Spent    Left  Speed\\n","100  172M  100  172M    0     0  55.8M      0  0:00:03  0:00:03 --:--:-- 55.8M\\n"],"name":"stdout"}]},{"metadata":{"id":"Btnjqad-GK0W","colab_type":"text"},"cell_type":"markdown","source":["### wget "]},{"metadata":{"id":"aELigXg7GNYh","colab_type":"code","colab":{}},"cell_type":"code","source":["! wget example.com\\n"],"execution_count":0,"outputs":[]},{"metadata":{"id":"DYoL4HWRGSQH","colab_type":"code","colab":{}},"cell_type":"code","source":["with open(\'index.html.1\',\'r\') as f:\\n","  for line in f:\\n","    print(line)"],"execution_count":0,"outputs":[]},{"metadata":{"id":"5npp3pVPFaVC","colab_type":"code","colab":{}},"cell_type":"code","source":["# check the file on fs\\n","! ls"],"execution_count":0,"outputs":[]},{"metadata":{"id":"H_j2NgNFFtWn","colab_type":"text"},"cell_type":"markdown","source":["### tar\\n"]},{"metadata":{"id":"v2f2p8iHFeYW","colab_type":"code","colab":{}},"cell_type":"code","source":["filename = \'lfw.tgz\'\\n","\\n","# Unzip the downloaded tar, write output of \\"tar\\" command to \\"filelist.txt\\"\\n","# the output is list of paths to all unzipped files. We can use them to read data. \\n","\\n","! tar xvzf $filename > filelist.txt"],"execution_count":0,"outputs":[]},{"metadata":{"id":"c6qr4-8pFpcj","colab_type":"text"},"cell_type":"markdown","source":["### zip"]},{"metadata":{"id":"HU4H7yVvFidW","colab_type":"code","colab":{}},"cell_type":"code","source":["filename = \'human_eva06.zip\'\\n","\\n","# Unzip the dataset\\n","! unzip $filename "],"execution_count":0,"outputs":[]},{"metadata":{"id":"fQTCuTTPF1yL","colab_type":"code","colab":{}},"cell_type":"code","source":[" "],"execution_count":0,"outputs":[]},{"metadata":{"id":"OM-jYKrGF5E5","colab_type":"text"},"cell_type":"markdown","source":["### Mount a google drive\\n"]},{"metadata":{"id":"ULycqrs5F7PY","colab_type":"code","colab":{}},"cell_type":"code","source":["from google.colab import drive"],"execution_count":0,"outputs":[]},{"metadata":{"id":"DZ-_6GBaGAOC","colab_type":"code","colab":{}},"cell_type":"code","source":["drive.mount(\'/content/drive\')"],"execution_count":0,"outputs":[]},{"metadata":{"id":"c8a_g_qPGDW1","colab_type":"code","colab":{}},"cell_type":"code","source":[""],"execution_count":0,"outputs":[]}]}\r\n---------314159265358979323846--' --compressed

# %% [markdown]
# ### wget

# %%
# !wget example.com

# %%
with open('index.html.2','r') as f:
  for line in f:
    print(line)

# %%
# check the file on fs
! ls -all

# %%
# %%HTML
# <!doctype html>
#
# <html>
#
# <head>
#
#     <title>Example Domain</title>
#
#
#
#     <meta charset="utf-8" />
#
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#
#     <style type="text/css">
#
#     body {
#
#         background-color: #f0f0f2;
#
#         margin: 0;
#
#         padding: 0;
#
#         font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#
#
#     }
#
#     div {
#
#         width: 600px;
#
#         margin: 5em auto;
#
#         padding: 50px;
#
#         background-color: #fff;
#
#         border-radius: 1em;
#
#     }
#
#     a:link, a:visited {
#
#         color: #38488f;
#
#         text-decoration: none;
#
#     }
#
#     @media (max-width: 700px) {
#
#         body {
#
#             background-color: #fff;
#
#         }
#
#         div {
#
#             width: auto;
#
#             margin: 0 auto;
#
#             border-radius: 0;
#
#             padding: 1em;
#
#         }
#
#     }
#
#     </style>
#
# </head>
#
#
#
# <body>
#
# <div>
#
#     <h1>Example Domain</h1>
#
#     <p>This domain is established to be used for illustrative examples in documents. You may use this
#
#     domain in examples without prior coordination or asking for permission.</p>
#
#     <p><a href="http://www.iana.org/domains/example">More information...</a></p>
#
# </div>
#
# </body>
#
# </html>

# %% [markdown]
# ### tar

# %%
filename = 'lfw.tgz'

# Unzip the downloaded tar, write output of "tar" command to "filelist.txt"
# the output is list of paths to all unzipped files. We can use them to read data. 

#! tar xvzf $filename > filelist.txt

something_toecho = "Hello bash!"
# !echo $something_toecho

# %% [markdown]
# ### zip

# %%
filename = 'human_eva06.zip'

# Unzip the dataset
! unzip $filename

# %%
 # !unzip 20_newsgroups-20190208T184834Z-001.zip

# %% [markdown]
# ### Mount a google drive

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')

# %%
# !ls drive/My\ Drive

# %%
! mkdir "Test directory from notebook"

# %%
! cd drive/My\ Drive && mkdir "Test directory from notebook"

# %%
# !ls drive/My\ Drive/Test\ directory\ from\ notebook
